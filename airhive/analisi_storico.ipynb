# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_pm = pd.read_json("dati_milano/pm10_11_18.json")

# %%
plt.plot(df_pm)

# %%
df_pm.max()
# Out:
# pm10    171
# dtype: int64

# %%
df_pm.min()
# Out:
# pm10    4
# dtype: int64
